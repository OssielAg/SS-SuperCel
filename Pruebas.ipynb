# %%
from src.Funciones import *

# %%
red1 = grafeno()
red2 = grafeno().mRot(30)

# %%
red1.showme()
red2.showme()

# %%
red3=superMesh((30,0),(0,30),[red1,red2])

# %%
red3.showme()

# %%
a,b = red1.getVectors()
sA, sB = m2V(a,b,(4,-4)), m2V(a,b,(4,8))
cAng(sA,sB)
# Out:
# 120.00000000000001

# %%
red3 = superMesh(sA,sB,[red1,red2])
red3.showme()

# %%
print(red3)
red3.exporta()
# Out:
# SuperLattice [Grafeno] [Grafeno(rot 30°)]
# 1.0
#         16.9048158819         -0.0000000000         0.0000000000
#         -8.4524079409         14.6400000000         0.0000000000
#         0.0000000000         0.0000000000         20.0000000000
# 	C
# 	210
# Direct
#      0.0833333333         0.0000000000         0.0001000000
#      0.1666666667         0.0000000000         0.0001000000
#      0.0000000000         0.0833333333         0.0001000000
#      0.0833333333         0.0833333333         0.0001000000
#      0.0000000000         0.1666666667         0.0001000000
#      0.3333333333         0.0000000000         0.0001000000
#      0.4166666667         0.0000000000         0.0001000000
#      0.2500000000         0.0833333333         0.0001000000
#      0.3333333333         0.0833333333         0.0001000000
#      0.1666666667         0.1666666667         0.0001000000
#      0.2500000000         0.1666666667         0.0001000000
# ...
