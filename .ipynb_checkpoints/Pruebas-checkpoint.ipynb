# %%
from src.Lattice  import *

# %%
a, b = (2.44, 0.0), (-1.22,math.sqrt(3)*(1.22))
p1, p2, p3, p4 = (1/3,2/3), (2/3,1/3), (1/3,-1/3), (4/3,2/3)
ats = [Atomo(p1, sig = 'C'), Atomo(p2, sig = 'C')]

# %%
red1=Red(a,b,atms=ats,name='Grafeno',enls=[(p1,p2),(p2,p3),(p2,p4)])

# %%
print(red1)
# Out:
# Grafeno
# 1.0
#         2.4400000000         0.0000000000         0.0000000000
#         -1.2200000000         2.1131019852         0.0000000000
#         0.0000000000         0.0000000000         10.0000000000
# 	C
# 	2
# Direct
#      0.3333333333         0.6666666667         0.0001000000
#      0.6666666667         0.3333333333         0.0001000000

# %%
red1.showXY(5,5)
# Out:
# 1

# %%
red2=red1.mRot(30)
print(red2)
red2.showXY(5,5)
# Out:
# Grafeno'
# 1.0
#         2.4400000000         -0.0000000000         0.0000000000
#         -1.2200000000         2.1131019852         0.0000000000
#         0.0000000000         0.0000000000         10.0000000000
# 	C
# 	2
# Direct
#      0.3333333333         0.6666666667         0.0001000000
#      0.6666666667         0.3333333333         0.0001000000
# 1

# %%
red2.getVectors()
# Out:
# ((2.1131019852340303, 1.2199999999999998),
#  (-2.11310198523403, 1.2200000000000002))

# %%
red1.exporta()
# Out:
# 1
